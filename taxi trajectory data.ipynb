# %% [markdown]
# # Check data as a beganning

# %%
import pandas as pd

file_path = 'train.csv'

df = pd.read_csv(file_path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1710670 entries, 0 to 1710669
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   TRIP_ID       int64
#  1   CALL_TYPE     object
#  2   ORIGIN_CALL   float64
#  3   ORIGIN_STAND  float64
#  4   TAXI_ID       int64
#  5   TIMESTAMP     int64
#  6   DAY_TYPE      object
#  7   MISSING_DATA  bool
#  8   POLYLINE      object
# dtypes: bool(1), float64(2), int64(3), object(3)
# memory usage: 106.0+ MB

# %% [markdown]
# # 📊 Dataset Overview: Porto Taxi Trajectories
#
# This dataset contains a **full year (01/07/2013 to 30/06/2014)** of taxi trip data from **442 taxis** operating in the city of **Porto, Portugal**. Each row in the dataset represents a **completed trip**, and the dataset includes detailed information about how the trip was requested, the taxi driver, the timestamp, and the GPS trajectory.
#
# ---
#
# ## 🔍 Column Descriptions
#
# | Column Name     | Type     | Description |
# |-----------------|----------|-------------|
# | **TRIP_ID**     | Integer   | A unique identifier for each trip. |
# | **CALL_TYPE**   | Char     | Describes how the trip was requested: <br> - `'A'`: Central dispatch (called by customer) <br> - `'B'`: Picked up at a taxi stand <br> - `'C'`: Hailed randomly on the street |
# | **ORIGIN_CALL** | Integer  | An anonymous ID for the customer who made the call (only present if `CALL_TYPE` = 'A'). `NaN` otherwise. |
# | **ORIGIN_STAND**| Integer  | ID of the taxi stand where the trip started (only present if `CALL_TYPE` = 'B'). `NaN` otherwise. |
# | **TAXI_ID**     | Integer  | A unique identifier for the taxi driver who completed the trip. |
# | **TIMESTAMP**   | Integer  | Unix timestamp representing the start time of the trip (in seconds). Can be converted to human-readable datetime. |
# | **DAYTYPE**     | Char     | Type of the day when the trip started: <br> - `'A'`: Normal day (workday or weekend) <br> - `'B'`: Holiday or special day <br> - `'C'`: Day before a holiday |
# | **MISSING_DATA**| Boolean  | `FALSE` means complete GPS data is present, `TRUE` indicates some GPS points are missing. |
# | **POLYLINE**    | String (List of Lists) | A list of GPS coordinates (longitude, latitude) recorded every 15 seconds during the trip. It shows the complete route taken by the taxi. The length of this list determines the trip duration. |
#
# ---
#
# ## 🎯 Prediction Target (for competition)
#
# The **total travel time** of a trip is defined as:
#
# **Trip Time (seconds)** = (Number of GPS points - 1) × 15
#
#
#
# ---
#
# ## 💡 Notes
# - Some fields like `ORIGIN_CALL` and `ORIGIN_STAND` are conditionally null depending on the `CALL_TYPE`.
# - The `POLYLINE` field contains valuable geo-spatial data but needs to be parsed from a string into a list.
# - The dataset is useful for tasks like **trip duration prediction**, **route clustering**, and **geo-spatial analysis**.

# %% [markdown]
# # Now let's check for outliters
# specially focusing on the timestamp

# %%
df.describe()
# Out:
#             TRIP_ID    ORIGIN_CALL   ORIGIN_STAND       TAXI_ID     TIMESTAMP
# count  1.710670e+06  364770.000000  806579.000000  1.710670e+06  1.710670e+06
# mean   1.388622e+18   24490.363018      30.272381  2.000035e+07  1.388622e+09
# std    9.180944e+15   19624.290043      17.747840  2.112405e+02  9.180944e+06
# min    1.372637e+18    2001.000000       1.000000  2.000000e+07  1.372637e+09
# 25%    1.380731e+18    6593.000000      15.000000  2.000017e+07  1.380731e+09
# 50%    1.388493e+18   18755.000000      27.000000  2.000034e+07  1.388493e+09
# 75%    1.396750e+18   40808.000000      49.000000  2.000052e+07  1.396750e+09
# max    1.404173e+18   63884.000000      63.000000  2.000098e+07  1.404173e+09

# %% [markdown]
# there is no anomilies in the timestamp indecating a valid data

# %% [markdown]
# # Make sure there is no duplicated trips by checking the trip ID

# %%
# pd.set_option('display.max_rows', None)
duplicated_trip_ids = df['TRIP_ID'].value_counts()[lambda x: x > 1]
duplicated_trip_ids
# Out:
# TRIP_ID
# 1397172149620000454    3
# 1402085470620000527    2
# 1389002485620000685    2
# 1393869017620000066    2
# 1389782974620000562    2
#                       ..
# 1400060661620000080    2
# 1394034338620000328    2
# 1373025987620000601    2
# 1394118360620000066    2
# 1373210896620000598    2
# Name: count, Length: 80, dtype: int64

# %% [markdown]
# ### 🕵️‍♂️ **NAUGHTY VALUES MUST BE PRUNED ASAP** 🤣
#
# After observing the previous results, we can clearly see that some trips exist more than once...
#
# You have **two options**:
#
# 1. **Option 1**: Delete only the **later occurrences** of each `TRIP_ID` (keeping the first occurrence).
# 2. **Option 2**: Delete **all duplicated instances**, effectively keeping only unique `TRIP_ID`s.

# %% [markdown]
# # Which option to choose?
# The idea is to check the other columns of each record to check if they are exactly the same
#
# 1. if they are the same you can keep one of them
# 2. if they are totally different then I would assume that this data is not accurate nor can be trusted so we will delete it all

# %%
df[df['TRIP_ID'].isin(duplicated_trip_ids.index)]
# Out:
#                      TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 3519     1372702836620000080         B          NaN          16.0  20000080
# 3720     1372702836620000080         C          NaN           NaN  20000080
# 21282    1373025987620000601         A       2002.0           NaN  20000601
# 21385    1373025987620000601         C          NaN           NaN  20000601
# 33228    1373210896620000598         B          NaN          57.0  20000598
# ...                      ...       ...          ...           ...       ...
# 1665302  1403407180620000242         C          NaN           NaN  20000242
# 1684526  1403716904620000337         C          NaN           NaN  20000337
# 1684739  1403716904620000337         C          NaN           NaN  20000337
# 1705646  1404093316620000307         B          NaN          57.0  20000307
# 1705665  1404093316620000307         C          NaN           NaN  20000307
#
#           TIMESTAMP DAY_TYPE  MISSING_DATA  \
# 3519     1372702836        A         False
# 3720     1372702836        A         False
# 21282    1373025987        A         False
# 21385    1373025987        A         False
# 33228    1373210896        A         False
# ...             ...      ...           ...
# 1665302  1403407180        A         False
# 1684526  1403716904        A         False
# 1684739  1403716904        A         False
# 1705646  1404093316        A         False
# 1705665  1404093316        A         False
#
#                                                   POLYLINE
# 3519         [[-8.635275,41.193729],[-8.634519,41.192901]]
# 3720     [[-8.62776,41.17554],[-8.62776,41.17554],[-8.6...
# 21282                                                   []
# 21385    [[-8.604108,41.182569],[-8.604072,41.182605],[...
# 33228                              [[-8.610885,41.145525]]
# ...                                                    ...
# 1665302                                                 []
# 1684526  [[-8.654913,41.182821],[-8.656623,41.182317],[...
# 1684739  [[-8.654913,41.182821],[-8.656623,41.182317],[...
# 1705646                            [[-8.610831,41.145741]]
# 1705665                             [[-8.61084,41.145732]]
#
# [161 rows x 9 columns]

# %% [markdown]
# # Prune them all 💣
# as observed above the data is completely different in each record and they are only 161 record which won't affect our data integrity at all

# %%
df = df[df['TRIP_ID'].duplicated(keep=False) == False]

df['TRIP_ID'].value_counts()[lambda x: x > 1] #Make sure they are deleted
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# # TimeStamp
# time stamp is not human readable nor understandable by a human therefore we must make a new datatime column

# %%
df['datetime'] = pd.to_datetime(df['TIMESTAMP'], unit='s')

df['datetime']
# Out:
# 0         2013-07-01 00:00:58
# 1         2013-07-01 00:08:23
# 2         2013-07-01 00:02:31
# 3         2013-07-01 00:00:54
# 4         2013-07-01 00:04:51
#                   ...
# 1710665   2014-06-30 23:37:43
# 1710666   2014-06-30 23:36:07
# 1710667   2014-01-03 10:41:56
# 1710668   2014-06-30 15:23:46
# 1710669   2014-06-30 19:39:07
# Name: datetime, Length: 1710509, dtype: datetime64[ns]

# %% [markdown]
# # Mapping Encoded Categories to Descriptive Labels
#
# First we make sure that there isn't any anomiies

# %%
df['CALL_TYPE'].unique()
# Out:
# array(['C', 'B', 'A'], dtype=object)

# %% [markdown]
# Now we start the mapping process

# %%
callTypeMap= {
'A' : 'Central',
'B' : 'Stand',
'C' : 'Street'
}

df['CALL_TYPE'] = df['CALL_TYPE'].map(callTypeMap)

# %%
df['CALL_TYPE'].unique()
# Out:
# array(['Street', 'Stand', 'Central'], dtype=object)

# %% [markdown]
# # Also map the day type so it can be meaningful

# %%
dayTypeMap={
    'A':'Normal', 
    'B':'Holiday',
    'C':'Before_Holiday'
}

df['DAY_TYPE'] = df['DAY_TYPE'].map(dayTypeMap)

# %%
df['DAY_TYPE'].unique()
# Out:
# array(['Normal'], dtype=object)

# %% [markdown]
# <span style="color:red">Something seems wrong here. Holidays are not classifed at all all days are classfied as NORMAL</span>

# %% [markdown]
# # Finding a solution to classify the days
#
# **there is a library called holidays that can help us with that problem**

# %%
import holidays

portugalHolidays= holidays.country_holidays('PT',subdiv='13') # Don't forget that this data is only based on the ciry Porto (13) in portugal and that is why we used its holidays specifically

portugalHolidays
# Out:
# False

# %% [markdown]
# **The function responsible for the parsing**

# %%
from datetime import timedelta

def modifyDayType(r):
    if r['datetime'] in portugalHolidays:
        r['DAY_TYPE'] = 'Holiday'
    elif (r['datetime'] + timedelta(days=1)) in portugalHolidays:
        r['DAY_TYPE'] = 'Before_Holiday'
    
    return r

# %% [markdown]
# Now we will satrt parsing **يارب يشتغل عشان معيطش**

# %%
df = df.apply(modifyDayType,axis=1)

# %%
df['DAY_TYPE'].unique()
# Out:
# array(['Normal', 'Before_Holiday', 'Holiday'], dtype=object)

# %% [markdown]
# **<span style="color:GREEN">IT FINALLY WORKEDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD :></span>**

# %%
df['DAY_TYPE'].value_counts()
# Out:
# DAY_TYPE
# Normal            1613820
# Before_Holiday      49997
# Holiday             46692
# Name: count, dtype: int64

# %%
df.count()
# Out:
# TRIP_ID         1710509
# CALL_TYPE       1710509
# ORIGIN_CALL      364765
# ORIGIN_STAND     806561
# TAXI_ID         1710509
# TIMESTAMP       1710509
# DAY_TYPE        1710509
# MISSING_DATA    1710509
# POLYLINE        1710509
# datetime        1710509
# dtype: int64

# %% [markdown]
# # Dealing with polylines 🥲🫢
# We can just delete all the data with missing coordinates, but where is the fun in that huh?
#
# `To reach the light, you must first go through the darkness.`

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(coord1, coord2): # This algorithm is responsible for accurately calcualting the distance between two points
    lon1, lat1 = coord1
    lon2, lat2 = coord2
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    km = 6371 * c
    return km

def interpolate_coords(coord1, coord2, num_points):
    lon1, lat1 = coord1
    lon2, lat2 = coord2
    lons = [lon1 + i*(lon2 - lon1)/(num_points+1) for i in range(1, num_points+1)]
    lats = [lat1 + i*(lat2 - lat1)/(num_points+1) for i in range(1, num_points+1)]
    return list(zip(lons, lats))

def calculate_total_distance(polyline):
    total_distance = 0
    for i in range(1, len(polyline)):
        total_distance += haversine(polyline[i-1], polyline[i])
    return total_distance

def calculate_time(polyline):
    total_time_minutes = 15 * (len(polyline) - 1)  / 60
    return total_time_minutes

# %%
def interpolate_polyline(polyline, threshold_km=0.3, max_interp_points=3):  #A function that will apply the interpolation to the polylines
    if len(polyline) < 2:
        return polyline
    
    fixed_polyline = [polyline[0]]
    
    for i in range(1, len(polyline)):
        prev = polyline[i-1]
        curr = polyline[i]
        dist = haversine(prev, curr)
        
        if dist > threshold_km:
            num_interp = min(int(dist // threshold_km), max_interp_points)
            new_points = interpolate_coords(prev, curr, num_interp)
            fixed_polyline.extend(new_points)
        
        fixed_polyline.append(curr)
    
    return fixed_polyline

# %% [markdown]
# # Parse the string literal to a list

# %%
# tempdf = df[df['MISSING_DATA'] == False]

import ast

df['POLYLINE_PARSED'] = df['POLYLINE'].apply(
    lambda x: [[coord[1], coord[0]] for coord in ast.literal_eval(x)]
)
df.drop('POLYLINE', axis=1, inplace=True) # Dropping this column to free up some memory
df['POLYLINE_PARSED']
# Out:
# 0          [[41.141412, -8.618643], [41.141376, -8.618499...
# 1          [[41.159826, -8.639847], [41.159871, -8.640351...
# 2          [[41.140359, -8.612964], [41.14035, -8.613378]...
# 3          [[41.151951, -8.574678], [41.151942, -8.574705...
# 4          [[41.18049, -8.645994], [41.180517, -8.645949]...
#                                  ...
# 1710665    [[41.14602, -8.612469], [41.145993, -8.612487]...
# 1710666    [[41.140845, -8.610138], [41.140935, -8.610174...
# 1710667                                                   []
# 1710668    [[41.154885, -8.630712], [41.154813, -8.63073]...
# 1710669    [[41.140629, -8.615538], [41.140746, -8.615421...
# Name: POLYLINE_PARSED, Length: 1710509, dtype: object

# %% [markdown]
# # How can we determine the best threshold?
# We can check the average speed in the complete polylines which will then determine the best threshold possible

# %%
# tempdf = df[df['MISSING_DATA'] == False]

# def calcAll(polyLine):
#      time = calculate_time(polyLine)
#      distance = calculate_total_distance(polyLine)
#      speed = distance/time
#      return distance,time,speed

df['Distance_KM'] = df['POLYLINE_PARSED'].apply(calculate_total_distance)


df['Distance_KM']
# Out:
# 0           3.182784
# 1           4.392363
# 2          22.424318
# 3          10.123073
# 4           5.903336
#              ...
# 1710665     3.312913
# 1710666     4.513655
# 1710667     0.000000
# 1710668     6.377982
# 1710669     2.652487
# Name: Distance_KM, Length: 1710509, dtype: float64

# %%
df['Distance_KM'].describe()
# Out:
# count    1.710509e+06
# mean     6.450295e+00
# std      8.844745e+00
# min      0.000000e+00
# 25%      2.777649e+00
# 50%      4.654364e+00
# 75%      7.799993e+00
# max      1.610191e+03
# Name: Distance_KM, dtype: float64

# %% [markdown]
# # Investigate distances that are 0

# %%
len(df[df['Distance_KM'] == 0])
# Out:
# 36621

# %% [markdown]
# # Prune them

# %%
df = df[df['Distance_KM'] != 0]

len(df[df['Distance_KM'] == 0])
# Out:
# 0

# %% [markdown]
# # Defind a function for boxplot and scatter plot to minimize code redundancy

# %%
import matplotlib.pyplot as plt
def boxPlot_ScaterPlot(points,name):


    plt.figure(figsize=(12, 5))

    # Boxplot
    plt.subplot(1, 2, 1)
    plt.boxplot(points, vert=False)
    plt.title(f"Boxplot of {name.split(" ")[0]}")
    plt.xlabel(name)

    # Scatter plot
    plt.subplot(1, 2, 2)
    plt.scatter(range(len(points)), points, color='skyblue')
    plt.title(f"{name.split(" ")[0]} Scatter Plot")
    plt.xlabel("Index")
    plt.ylabel(name)

    # # Highlight values greater than a threshold as outliers (you can adjust this)
    # threshold = distances_km.mean() + 3 * distances_km.std()
    # for i, value in enumerate(distances_km):
    #     if value > threshold:
    #         plt.scatter(i, value, color='red')
    #         plt.text(i, value + 20, f"{value:.2f} km", color='red', ha='center')

    plt.tight_layout()
    return plt.show()

# %% [markdown]
# # There is clearly an outlier which we need to deal with first
#
# Let's visualise it first

# %%
boxPlot_ScaterPlot(df['Distance_KM'],'Distance (KM)')

# %% [markdown]
# # Using IQR for efficiency and fast parsing

# %%
Q1 = df['Distance_KM'].quantile(0.25)
Q3 = df['Distance_KM'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR


df = df[(df['Distance_KM'] >= lower_bound) & (df['Distance_KM'] <= upper_bound) ]

df['Distance_KM'].describe()
# Out:
# count    1.561442e+06
# mean     5.273953e+00
# std      3.348670e+00
# min      9.892410e-04
# 25%      2.775135e+00
# 50%      4.462410e+00
# 75%      6.997646e+00
# max      1.544591e+01
# Name: Distance_KM, dtype: float64

# %% [markdown]
# # Visualize again

# %%
boxPlot_ScaterPlot(df['Distance_KM'],'Distance (KM)')

# %%
df[df['Distance_KM'] < 1] #Very short trips won't be pruned
# Out:
#                      TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 25       1372639092620000233    Street          NaN           NaN  20000233
# 68       1372637926620000173    Street          NaN           NaN  20000173
# 100      1372638513620000473   Central      63882.0           NaN  20000473
# 120      1372642351620000005    Street          NaN           NaN  20000005
# 137      1372640078620000333    Street          NaN           NaN  20000333
# ...                      ...       ...          ...           ...       ...
# 1710603  1404172736620000483    Street          NaN           NaN  20000483
# 1710615  1404165476620000243    Street          NaN           NaN  20000243
# 1710622  1376053063620000981    Street          NaN           NaN  20000981
# 1710648  1404171548620000364    Street          NaN           NaN  20000364
# 1710663  1388660427620000585    Street          NaN           NaN  20000585
#
#           TIMESTAMP DAY_TYPE  MISSING_DATA            datetime  \
# 25       1372639092   Normal         False 2013-07-01 00:38:12
# 68       1372637926   Normal         False 2013-07-01 00:18:46
# 100      1372638513   Normal         False 2013-07-01 00:28:33
# 120      1372642351   Normal         False 2013-07-01 01:32:31
# 137      1372640078   Normal         False 2013-07-01 00:54:38
# ...             ...      ...           ...                 ...
# 1710603  1404172736   Normal         False 2014-06-30 23:58:56
# 1710615  1404165476   Normal         False 2014-06-30 21:57:56
# 1710622  1376053063   Normal         False 2013-08-09 12:57:43
# 1710648  1404171548   Normal         False 2014-06-30 23:39:08
# 1710663  1388660427   Normal         False 2014-01-02 11:00:27
#
#                                            POLYLINE_PARSED  Distance_KM
# 25       [[41.168295, -8.632737], [41.16825, -8.6328], ...     0.027935
# 68         [[41.173335, -8.642133], [41.172831, -8.64081]]     0.157199
# 100      [[41.181759, -8.601273], [41.181768, -8.601246...     0.053296
# 120      [[41.149953, -8.614107], [41.14998, -8.614746]...     0.767187
# 137      [[41.149161, -8.599257], [41.148387, -8.598492...     0.624506
# ...                                                    ...          ...
# 1710603  [[41.175504, -8.58609], [41.174955, -8.586351]...     0.521707
# 1710615     [[41.158674, -8.5779], [41.158683, -8.577891]]     0.001407
# 1710622  [[41.162454, -8.623521], [41.162697, -8.623701...     0.038364
# 1710648  [[41.123385, -8.614323], [41.123385, -8.614152...     0.104010
# 1710663  [[41.162283, -8.60697], [41.16231, -8.60697], ...     0.920170
#
# [47372 rows x 11 columns]

# %% [markdown]
# # Calcualte time

# %%
df['Trip_duration_mins'] = df['POLYLINE_PARSED'].apply(calculate_time)

df['Trip_duration_mins'].describe()
# Out:
# count    1.561442e+06
# mean     1.094202e+01
# std      6.920684e+00
# min      2.500000e-01
# 25%      6.750000e+00
# 50%      9.750000e+00
# 75%      1.350000e+01
# max      4.987500e+02
# Name: Trip_duration_mins, dtype: float64

# %% [markdown]
# # Prune outliers

# %%
Q1 = df['Trip_duration_mins'].quantile(0.25)
Q3 = df['Trip_duration_mins'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR #Some trips might be long and that is okay but here we are focusing on the mean so i will delete most long trips to get a good average
upper_bound = Q3 + 1.5 * IQR


df = df[(df['Trip_duration_mins'] >= lower_bound) & (df['Trip_duration_mins'] <= upper_bound) ]

df['Trip_duration_mins'].describe()
# Out:
# count    1.503067e+06
# mean     1.009146e+01
# std      4.693743e+00
# min      2.500000e-01
# 25%      6.500000e+00
# 50%      9.500000e+00
# 75%      1.300000e+01
# max      2.350000e+01
# Name: Trip_duration_mins, dtype: float64

# %%
boxPlot_ScaterPlot(df['Trip_duration_mins'],'time (mins)')

# %% [markdown]
# # Claculae speed

# %%
df['Speed_KPH'] = df['Distance_KM'] / (df['Trip_duration_mins'] / 60)

df['Speed_KPH'].describe()
# Out:
# count    1.503067e+06
# mean     3.083008e+01
# std      1.766137e+01
# min      4.803621e-02
# 25%      2.107565e+01
# 50%      2.779199e+01
# 75%      3.720467e+01
# max      2.123982e+03
# Name: Speed_KPH, dtype: float64

# %% [markdown]
# # Prune outliers in speed

# %%
boxPlot_ScaterPlot(df['Speed_KPH'],'Speed (KPH)')

# %% [markdown]
# # Clean speed outliers

# %%
Q1 = df['Speed_KPH'].quantile(0.25)
Q3 = df['Speed_KPH'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR #Some trips might be long and that is okay but here we are focusing on the mean so i will delete most long trips to get a good average
upper_bound = Q3 + 1.5 * IQR


df = df[(df['Speed_KPH'] >= lower_bound) & (df['Speed_KPH'] <= upper_bound) ]

df['Speed_KPH'].describe()
# Out:
# count    1.447506e+06
# mean     2.898835e+01
# std      1.150371e+01
# min      4.803621e-02
# 25%      2.081997e+01
# 50%      2.726893e+01
# 75%      3.581620e+01
# max      6.139810e+01
# Name: Speed_KPH, dtype: float64

# %% [markdown]
# # Visualize again

# %%
boxPlot_ScaterPlot(df['Speed_KPH'],'Speed (KPH)')

# %% [markdown]
# # Insights
# The average speed of a trip is around 30 this number will help us in calcuating the interpolition line in the missing data
#
# `All of this just for getting the mean of the speed, I might as well just KMS🥲`
#
#
# **Don't forget to delete useless variables that are no longer needed**

# %%
# import gc
# # del tempdf, pruned, upper_bound, lower_bound, distances_km, Trip_duration_mins
# gc.collect()

# %% [markdown]
# <span style="color:red">The cell above was commented out due to changes that made code more efficient so no longer need for it</span>

# %% [markdown]
# # HI there
# this markdown cell is from the furutre and it is telling you to flip the langtitude and latitude before it is too late
#
# **you probole don't understand so let me explain for you... the polyline points right now is formated (lon,lat) which is too confusing when working with and mapping**

# %%
# df['POLYLINE_PARSED'] = df['POLYLINE_PARSED'].apply(  #This will probably take some time
#     lambda polyline: [[lat, lon] for lon, lat in polyline]
# )

# %% [markdown]
# `The above cell was combined with the polyline parsing step`

# %% [markdown]
# # Create a function that visualizes trips to minimize code redundancy

# %%
import folium
def MapPlot(polyline_points):
    # polyline_points = [[lat, lon] for lon, lat in points]
    length = len(polyline_points)


        
    # Center map on Porto
    m = folium.Map(location=[sum(x[0] for x in polyline_points)/length, sum(x[1] for x in polyline_points)/length], zoom_start=14)


    for lat, lon in polyline_points:
        folium.Marker([lat, lon]).add_to(m)

    folium.PolyLine(polyline_points, color="blue", weight=2.5, opacity=1).add_to(m)

    folium.Marker([polyline_points[0][0], polyline_points[0][1]], popup="Start", icon=folium.Icon(color="green")).add_to(m)
    folium.Marker([polyline_points[-1][0], polyline_points[-1][1]], popup="End", icon=folium.Icon(color="red")).add_to(m)
    return m

# %%
points = list(df.iloc[0]['POLYLINE_PARSED'])
MapPlot(points)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d2441f527129abfaea91c205225ca55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d2441f527129abfaea91c205225ca55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d2441f527129abfaea91c205225ca55 = L.map(
#                 &quot;map_6d2441f527129abfaea91c205225ca55&quot;,
#                 {
#                     center: [41.14919347826087, -8.628016304347826],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01151b334d7f84e9dbd2e0adee440e32 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_01151b334d7f84e9dbd2e0adee440e32.addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_877485ab7f06205510814088219bfd6f = L.marker(
#                 [41.141412, -8.618643],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_90c3372854e67cb2863a9410262d8b4b = L.marker(
#                 [41.141376, -8.618499],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_0ed8884a86d8d4ac0ec8d1924aa1210f = L.marker(
#                 [41.14251, -8.620326],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_ae92b974d0181d51c5085df694dbed7c = L.marker(
#                 [41.143815, -8.622153],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_a956c118358dab563781fda1ab44722b = L.marker(
#                 [41.144373, -8.623953],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_351f23d38bb6af12ca8959c2a59b660d = L.marker(
#                 [41.144778, -8.62668],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_11c518fe8ce9a884458913d62380ec5a = L.marker(
#                 [41.144697, -8.627373],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_4fa66a103c7bfc68f88ce4b74908a49d = L.marker(
#                 [41.14521, -8.630226],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_6d59c17cf8645466428f94282da448a0 = L.marker(
#                 [41.14692, -8.632746],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_dd3875110d0eac4f9fba095215fe519e = L.marker(
#                 [41.148225, -8.631738],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_c5879c87272711b0beb00b71bb8514b7 = L.marker(
#                 [41.150385, -8.629938],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_97fff27b6029aaef3bfafaed0aeb3b83 = L.marker(
#                 [41.151213, -8.62911],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_8f1edaa82cf4b2658a967575e17e471d = L.marker(
#                 [41.15124, -8.629128],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_c325d6929a1f954afdbad67121af4574 = L.marker(
#                 [41.152203, -8.628786],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_9670bf5be67fb0d8781759a0c6b1910c = L.marker(
#                 [41.152374, -8.628687],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_bc3f262e2de0dd84fd345a573e5a6b0e = L.marker(
#                 [41.152518, -8.628759],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_de11044dffb75d289ef99eb8262f0c80 = L.marker(
#                 [41.15268, -8.630838],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_d8855597a7a12511594b545e03720942 = L.marker(
#                 [41.153022, -8.632323],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_6a96786288c668300995561f77c7ed99 = L.marker(
#                 [41.154489, -8.631144],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_52b185f1b19357218289131aeef5d3ad = L.marker(
#                 [41.154507, -8.630829],
#                 {
# }
#             ).addTo(map_6d2441f527129abfaea91c205225ca55);
#
#
#             var marker_49b65b9ed98b0f90b03c7f8f470326a6 = L.marker(

# %% [markdown]
# # Visualize a trip with missing points

# %%
points = list(df[df['MISSING_DATA'] == True].iloc[0]['POLYLINE_PARSED'])
MapPlot(points)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3afe2445003a9781d22bbdd076dbede2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3afe2445003a9781d22bbdd076dbede2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3afe2445003a9781d22bbdd076dbede2 = L.map(
#                 &quot;map_3afe2445003a9781d22bbdd076dbede2&quot;,
#                 {
#                     center: [41.134872558139534, -8.608692558139536],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0a7263dbfb917378c933ce28b8abfd1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0a7263dbfb917378c933ce28b8abfd1.addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_5e134e93f071d8402d87030d0a6cb07a = L.marker(
#                 [41.145975, -8.612559],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_017a46e5b5b89f23abd8470bcee84f06 = L.marker(
#                 [41.145975, -8.612577],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_b04fbe328b9c1184c2e41b32aa9e844b = L.marker(
#                 [41.145966, -8.612586],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_c6094405637d5340d54dd2c7227a7770 = L.marker(
#                 [41.145984, -8.612559],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_1dcfbb2580062ce965abce62602a5ada = L.marker(
#                 [41.145966, -8.612127],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_d601ad897d73c8e41900a537663dc5d5 = L.marker(
#                 [41.146092, -8.611767],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_4b6ed9a2ca06b07d15e3c5fb09b9750d = L.marker(
#                 [41.145813, -8.610849],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_fc41607e23618df6c45c75d840bde5f3 = L.marker(
#                 [41.145336, -8.610966],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_88da90bd6c8d7a3ab157c99e2eb45ce2 = L.marker(
#                 [41.145318, -8.610948],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_259447dddb4b44e46bc1aeee199517dd = L.marker(
#                 [41.145318, -8.610948],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_0b9f6abc4dfacbb052b9adf625ba5548 = L.marker(
#                 [41.144445, -8.611893],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_f0aeaee10dffb17e4ed55b7f5c42abd8 = L.marker(
#                 [41.142933, -8.61399],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_0f5c53d162edfe4b32167c962a9a3651 = L.marker(
#                 [41.142852, -8.61489],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_0ec468915d29abdfdd065e6b5a264c5e = L.marker(
#                 [41.141817, -8.615322],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_8aacf5d43c04e8e8d38d19052dbda94f = L.marker(
#                 [41.140899, -8.614953],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_914e12f147e050c612ec107067c265f5 = L.marker(
#                 [41.141538, -8.613153],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_d28f25af45d946f17edb1f757de32751 = L.marker(
#                 [41.140458, -8.609625],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_bd77a96687932304c747c76c1417d4e3 = L.marker(
#                 [41.139, -8.609337],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_540ef5f985abca500e73d68a31ae4d5a = L.marker(
#                 [41.137929, -8.610435],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_ba1149ee4387b602fd948c128af8e6e8 = L.marker(
#                 [41.136471, -8.611488],
#                 {
# }
#             ).addTo(map_3afe2445003a9781d22bbdd076dbede2);
#
#
#             var marker_3ecfa56052ac1dfe710ec312697132e5 = L.marker(

# %% [markdown]
# # An observation
# Using interpolation won't be accurate because it might map to point that is not a road... we need something more accurate
#
# **For now we need to stick with basic interpolition and the haversine function because if we want more accurate data we need an external API like google maps API to accurately calcualting the distance and other values**
#
# `Maybe in the future when I'm rich, I will do it using the google maps API💰💸`

# %% [markdown]
# # Testing the interpolation algoirthm on one record
# -  First we will create a function that shows the new points
#
# `Points that are greyish are the points that have been added`

# %%
def mapPointsDiff(polyline_points,thershold=0.3):
    length = len(polyline_points)

    newPoints = interpolate_polyline(polyline_points,thershold)
        
    # Center map on Porto
    m = folium.Map(location=[sum(x[0] for x in polyline_points)/length, sum(x[1] for x in polyline_points)/length], zoom_start=14)


    for lat, lon in newPoints:
        folium.Marker([lat, lon],icon=folium.Icon(color='cadetblue')).add_to(m)

        
    for lat, lon in polyline_points:
        folium.Marker([lat,lon],icon=folium.Icon(color='blue')).add_to(m)

    folium.PolyLine(newPoints, color="blue", weight=2.5, opacity=1).add_to(m)

    folium.Marker([polyline_points[0][0], polyline_points[0][1]], popup="Start", icon=folium.Icon(color="green")).add_to(m)
    folium.Marker([polyline_points[-1][0], polyline_points[-1][1]], popup="End", icon=folium.Icon(color="red")).add_to(m)
    return m

# %%
r = df[df['MISSING_DATA'] == True].iloc[0] 
    
mapPointsDiff(r['POLYLINE_PARSED'],0.4)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f08a154132297742c817f2628abb1cf8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f08a154132297742c817f2628abb1cf8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f08a154132297742c817f2628abb1cf8 = L.map(
#                 &quot;map_f08a154132297742c817f2628abb1cf8&quot;,
#                 {
#                     center: [41.134872558139534, -8.608692558139536],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e7e235016fcd191a31260fb46655a47 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4e7e235016fcd191a31260fb46655a47.addTo(map_f08a154132297742c817f2628abb1cf8);
#
#
#             var marker_17cc0e78133cb1e432e15776c4afba1d = L.marker(
#                 [41.145975, -8.612559],
#                 {
# }
#             ).addTo(map_f08a154132297742c817f2628abb1cf8);
#
#
#             var icon_1b87b478889869992d7efa1dbe2a3e8b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;cadetblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_17cc0e78133cb1e432e15776c4afba1d.setIcon(icon_1b87b478889869992d7efa1dbe2a3e8b);
#
#
#             var marker_1bff06286b3413a3372e39f5eb4b19d9 = L.marker(
#                 [41.145975, -8.612577],
#                 {
# }
#             ).addTo(map_f08a154132297742c817f2628abb1cf8);
#
#
#             var icon_8a20cc4aa452005b9d23ad96e0aeff35 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;cadetblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_1bff06286b3413a3372e39f5eb4b19d9.setIcon(icon_8a20cc4aa452005b9d23ad96e0aeff35);
#
#
#             var marker_bf299b590c791a98418c3f4b50dce353 = L.marker(
#                 [41.145966, -8.612586],
#                 {
# }
#             ).addTo(map_f08a154132297742c817f2628abb1cf8);
#
#
#             var icon_f3daec1615966df4269a7232919b1a33 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;cadetblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_bf299b590c791a98418c3f4b50dce353.setIcon(icon_f3daec1615966df4269a7232919b1a33);
#
#
#             var marker_c0ceab37706158735924581e7aba5629 = L.marker(
#                 [41.145984, -8.612559],
#                 {
# }
#             ).addTo(map_f08a154132297742c817f2628abb1cf8);
#
#
#             var icon_43704fca006cd8dae3e4ba28dc9a3625 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;cadetblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_c0ceab37706158735924581e7aba5629.setIcon(icon_43704fca006cd8dae3e4ba28dc9a3625);
#
#
#             var marker_f4c9efb5adf7fd86bd4195d02a857587 = L.marker(
#                 [41.145966, -8.612127],
#                 {
# }
#             ).addTo(map_f08a154132297742c817f2628abb1cf8);
#
#
#             var icon_1181b71e53fed6b5f4e9b627a5c227cc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;cadetblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_f4c9efb5adf7fd86bd4195d02a857587.setIcon(icon_1181b71e53fed6b5f4e9b627a5c227cc);
#
#
#             var marker_678f40c046e483a45090abbc89e7165c = L.marker(
#                 [41.146092, -8.611767],
#                 {
# }
#             ).addTo(map_f08a154132297742c817f2628abb1cf8);
#
#
#             var icon_8b9dee7282c4d8772bdb443fd5edaf6a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;cadetblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_678f40c046e483a45090abbc89e7165c.setIcon(icon_8b9dee7282c4d8772bdb443fd5edaf6a

# %% [markdown]
# <span style="color:green">Interpolition seems good</span>

# %%
df.loc[df['MISSING_DATA'] == True, 'POLYLINE_PARSED'] = df.loc[
    df['MISSING_DATA'] == True, 'POLYLINE_PARSED'
].apply(lambda x: interpolate_polyline(x, threshold_km=0.3))

# %%
r = df[df['MISSING_DATA'] == True].iloc[2] 
    
MapPlot(r['POLYLINE_PARSED'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12d47e076688a449113bef07ab544048 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12d47e076688a449113bef07ab544048&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12d47e076688a449113bef07ab544048 = L.map(
#                 &quot;map_12d47e076688a449113bef07ab544048&quot;,
#                 {
#                     center: [41.15214795, -8.6195499],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5baf1ad85b9fa9b8aa1f5b899fffa9c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b5baf1ad85b9fa9b8aa1f5b899fffa9c.addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_f4ee63693471afd8825078871de55a1f = L.marker(
#                 [41.160276, -8.609697],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_5d2c0268628b8c6a1a2d08dd208224b1 = L.marker(
#                 [41.16033, -8.609571],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_3e39d8152f7b094dd4841482bf041999 = L.marker(
#                 [41.160231, -8.609688],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_059b6eb59701c9a0c109ca78f449fac6 = L.marker(
#                 [41.160024, -8.609904],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_49e8681540142f7f4c8b184f5abc5664 = L.marker(
#                 [41.158359, -8.609967],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_811474cbbd63af296f2149c7fca5f6ce = L.marker(
#                 [41.156298, -8.610138],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_bc95d161f8606341590176ebc44f30be = L.marker(
#                 [41.154192, -8.610183],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_b721d4bf7d28072053d08ddf54298402 = L.marker(
#                 [41.152302, -8.610012],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_205b8481b31dbbf7d96410b7c051f9ef = L.marker(
#                 [41.150817, -8.610921],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_0aa91322cf4f72e1a85c351cafee7dda = L.marker(
#                 [41.149647, -8.611362],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_5c0cc8b36898fdbb904f8df9bc956d98 = L.marker(
#                 [41.148117, -8.611254],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_c61276a451ca13c9a360907750f5160f = L.marker(
#                 [41.148081, -8.61228],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_9f22b3d1debc8ce399abbaf51fb2e30f = L.marker(
#                 [41.14795275, -8.6145975],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_fc269d98531332da365a9cfdf00de95a = L.marker(
#                 [41.1478245, -8.616914999999999],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_c3585142fa2c657ed8a8748807e51f40 = L.marker(
#                 [41.147696249999996, -8.619232499999999],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_725178c963411863f26f420b85c79bca = L.marker(
#                 [41.147568, -8.62155],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_2e05f2166fb65068ed809e18c8cfc451 = L.marker(
#                 [41.147739, -8.62245],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_f535e3aaa9930bab7a27f876bbf16194 = L.marker(
#                 [41.147847, -8.622828],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_c5176c0a2d943431838226efa3338f06 = L.marker(
#                 [41.14854, -8.624952],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_264b32d342ffae7fff640eadacdf70d7 = L.marker(
#                 [41.150214, -8.625843],
#                 {
# }
#             ).addTo(map_12d47e076688a449113bef07ab544048);
#
#
#             var marker_ca9c11c4b878b7dfc0fbd27bb367ed40 = L.mark

# %%
df[df['MISSING_DATA'] == True]
# Out:
#                     TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 105621  1374554455620000625     Stand          NaN          23.0  20000625
# 782321  1387137779620000640    Street          NaN           NaN  20000640
# 848552  1388351478620000678   Central       9738.0           NaN  20000678
# 932391  1390005983620000640    Street          NaN           NaN  20000640
#
#          TIMESTAMP DAY_TYPE  MISSING_DATA            datetime  \
# 105621  1374554455   Normal          True 2013-07-23 04:40:55
# 782321  1387137779   Normal          True 2013-12-15 20:02:59
# 848552  1388351478   Normal          True 2013-12-29 21:11:18
# 932391  1390005983   Normal          True 2014-01-18 00:46:23
#
#                                           POLYLINE_PARSED  Distance_KM  \
# 105621  [[41.145975, -8.612559], [41.145975, -8.612577...     5.105386
# 782321  [[41.161941, -8.604558], [41.162013, -8.604477...     9.751256
# 848552  [[41.160276, -8.609697], [41.16033, -8.609571]...     4.053854
# 932391  [[41.16123, -8.604792], [41.161167, -8.604801]...     1.693427
#
#         Trip_duration_mins  Speed_KPH
# 105621               10.50  29.173636
# 782321               12.50  46.806027
# 848552                6.50  37.420193
# 932391                3.25  31.263263

# %% [markdown]
# # Recalculate Distance, Time and speed

# %%
def reCalc(r):
    # r['Distance_KM'] = calculate_total_distance(r['POLYLINE_PARSED']) since the points are plotted between each point the distance will never change in any case
    r['Trip_duration_mins'] = calculate_time(r['POLYLINE_PARSED'])
    r['Speed_KPH'] = r['Distance_KM'] / (r['Trip_duration_mins'] / 60)
    return r

df.loc[df['MISSING_DATA'] == True] = df.loc[df['MISSING_DATA'] == True].apply(reCalc, axis=1)

df.loc[df['MISSING_DATA'] == True]
# Out:
#                     TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 105621  1374554455620000625     Stand          NaN          23.0  20000625
# 782321  1387137779620000640    Street          NaN           NaN  20000640
# 848552  1388351478620000678   Central       9738.0           NaN  20000678
# 932391  1390005983620000640    Street          NaN           NaN  20000640
#
#          TIMESTAMP DAY_TYPE  MISSING_DATA            datetime  \
# 105621  1374554455   Normal          True 2013-07-23 04:40:55
# 782321  1387137779   Normal          True 2013-12-15 20:02:59
# 848552  1388351478   Normal          True 2013-12-29 21:11:18
# 932391  1390005983   Normal          True 2014-01-18 00:46:23
#
#                                           POLYLINE_PARSED  Distance_KM  \
# 105621  [[41.145975, -8.612559], [41.145975, -8.612577...     5.105386
# 782321  [[41.161941, -8.604558], [41.162013, -8.604477...     9.751256
# 848552  [[41.160276, -8.609697], [41.16033, -8.609571]...     4.053854
# 932391  [[41.16123, -8.604792], [41.161167, -8.604801]...     1.693427
#
#         Trip_duration_mins  Speed_KPH
# 105621               11.00  27.847562
# 782321               13.75  42.550934
# 848552                7.25  33.549139
# 932391                3.75  27.094828

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center;">
#   <img src="whatdiditcostyoumeme.jpg" style="width: 95%;" />
# </div>
